# %%
# Following two lines make sure anything imported from .py scripts 
# is automatically reloaded if edited & saved (e.g. local unit tests or players)
# %load_ext autoreload
# %autoreload 2
from explorable_graph import ExplorableGraph
import osm2networkx
from search_submission_tests import TestPriorityQueue, TestBasicSearch, TestBidirectionalSearch
import search_submission_tests_grid
from search_unit_tests import SearchUnitTests
import test_race
import visualize_graph
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %reload_ext autoreload

# %%
import unittest
tests = TestPriorityQueue()
tests.test_append_and_pop()
tests.test_fifo_property()

# %%
tests = TestBasicSearch()
test1 = SearchUnitTests()
test1.setUp()
tests.setUp()
tests.test_bfs()
tests.test_bfs_empty_path()
test1.test_bfs_romania()

# %%
tests = TestBasicSearch()
test1 = SearchUnitTests()
test1.setUp()
tests.setUp()
tests.test_ucs()
test1.test_ucs_romania()

# %%
tests = TestBasicSearch()
test1 = SearchUnitTests()
test1.setUp()
tests.setUp()
tests.test_a_star()
test1.test_a_star_euclidean_romania()

# %%
tests = TestBidirectionalSearch()
test1 = SearchUnitTests()
test1.setUp()
tests.setUp()
tests.test_bidirectional_ucs()
test1.test_bi_ucs_romania()
# Out:
# [(0, '69581003')]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-89-acee3e47fe65> in <module>
#       3 test1.setUp()
#       4 tests.setUp()
# ----> 5 tests.test_bidirectional_ucs()
#       6 test1.test_bi_ucs_romania()
#
# ~\desktop\assignment_2\search_submission_tests.py in test_bidirectional_ucs(self)
#     155     def test_bidirectional_ucs(self):
#     156         """Test and generate GeoJSON for bidirectional UCS search"""
# --> 157         path = bidirectional_ucs(self.atlanta, '69581003', '69581000')
#     158         all_explored = self.atlanta.explored_nodes
#     159         plot_search(self.atlanta, 'atlanta_search_bidir_ucs.json', path,
#
# ~\desktop\assignment_2\submission.py in bidirectional_ucs(graph, start, goal)
#     458                         path_string = str(patha) + str(pathb.reverse())
# ...

# %%
tests = TestBidirectionalSearch()
test1 = SearchUnitTests()
test1.setUp()
tests.setUp()
tests.test_bidirectional_a_star()
test1.test_bi_a_star_null_romania()
test1.test_bi_a_star_euclidean_romania()
test1.test_bi_a_star_haversine_atlanta()
# Out:
# []
# done writing nodes to file
# done writing edges to file
# []
# []
# []
# []
# []
# [(75, 1, 'a,z'), (85, 2, 'u,b')]
# [(75, 1, 'a,z'), (85, 2, 'u,b'), (118, 1, 'a,t'), (90, 2, 'g,b')]
# [(75, 1, 'a,z'), (85, 2, 'u,b'), (118, 1, 'a,t'), (90, 2, 'g,b'), (140, 1, 'a,s'), (101, 2, 'p,b')]
# [(85, 2, 'u,b'), (118, 1, 'a,t'), (90, 2, 'g,b'), (140, 1, 'a,s'), (101, 2, 'p,b'), (146, 1, 'a,z,o'), (211, 2, 'f,b')]
# [(85, 2, 'u,b'), (118, 1, 'a,t'), (90, 2, 'g,b'), (101, 2, 'p,b'), (146, 1, 'a,z,o'), (211, 2, 'f,b'), (220, 1, 'a,s,r')]
# [(85, 2, 'u,b'), (90, 2, 'g,b'), (101, 2, 'p,b'), (146, 1, 'a,z,o'), (211, 2, 'f,b'), (220, 1, 'a,s,r'), (229, 1, 'a,t,l')]
# [(85, 2, 'u,b'), (90, 2, 'g,b'), (101, 2, 'p,b'), (146, 1, 'a,z,o'), (211, 2, 'f,b'), (220, 1, 'a,s,r'), (229, 1, 'a,t,l'), (239, 1, 'a,s,f')]
# [(85, 2, 'u,b'), (90, 2, 'g,b'), (101, 2, 'p,b'), (146, 1, 'a,z,o'), (211, 2, 'f,b'), (220, 1, 'a,s,r'), (229, 1, 'a,t,l'), (239, 1, 'a,s,f'), (291, 1, 'a,s,o')]
# ...

# %%
tests = TestBidirectionalSearch()
test1 = SearchUnitTests()
test1.setUp()
tests.setUp()
test1.test_tri_ucs_romania()
# Out:
# 3 return happening
# a = a
# s = s
# ['a', 's']
# [['a', 's']]
# PQ:[(140, 2, 'a,s')]
# PQ:[(118, 3, 'a,t'), (140, 2, 'a,s')]
# 2 return happening
# [['a', 's'], ['a', 'z']]
# PQ:[(75, 4, 'a,z'), (140, 2, 'a,s'), (118, 3, 'a,t')]
# 5 return happening
# [['a', 's'], ['a', 'z'], ['a', 'z']]
# PQ:[(75, 2, 'a,z')]
# PQ:[(71, 3, 'o,z'), (75, 2, 'a,z')]
# 8 return happening
# [['a', 's'], ['a', 'z'], ['a', 'z'], ['a', 's']]
# PQ:[(140, 2, 'a,s')]
# PQ:[(99, 3, 'f,s'), (140, 2, 'a,s')]
# PQ:[(99, 3, 'f,s'), (140, 2, 'a,s'), (151, 4, 'o,s')]
# PQ:[(80, 5, 'r,s'), (99, 3, 'f,s'), (151, 4, 'o,s'), (140, 2, 'a,s')]
# 4 return happening
# [['a', 's'], ['a', 'z'], ['a', 'z'], ['a', 's'], ['a', 'z']]
# 7 return happening
# [['a', 's'], ['a', 'z'], ['a', 'z'], ['a', 's'], ['a', 'z'], ['a', 'z']]
# 1 return happening
# [['a', 's'], ['a', 'z'], ['a', 'z'], ['a', 's'], ['a', 'z'], ['a', 'z'], ['a', 'z']]
# ['a', 's', 'z']
# ---------------------------------------------------------------------------
# ...
